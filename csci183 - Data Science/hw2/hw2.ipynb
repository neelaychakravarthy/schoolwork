# %%
import pandas as pd

housing = pd.read_csv('housing.csv')

housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
kc_house_data = pd.read_csv('kc_house_data.csv')
kc_house_data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#Question 1
housing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
kc_house_data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#Question 2
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
kc_house_data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#Questions 3

housing.select_dtypes(include=['float64'])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
kc_house_data.select_dtypes(include=['float64', 'int64'])
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
#Question 4
housing_numerical = housing.select_dtypes(include=['float64'])
print("With median house value as the target column, the column with high correlation to the target feature is median income")
housing_numerical.corr()
# Out:
# With median house value as the target column, the column with high correlation to the target feature is median income
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# ...

# %%
kc_house_data_numerical = kc_house_data.select_dtypes(include=['float64', 'int64'])
print("With price as the target column, features strongly correlated with price are sqft_living, grade, sqft_above, and sqft_living15")
kc_house_data_numerical.corr()
# Out:
# With price as the target column, features strongly correlated with price are sqft_living, grade, sqft_above, and sqft_living15
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# ...

# %%
#Question 5
import pandas as pd
housing = pd.read_csv('housing.csv')
housing_numerical = housing.select_dtypes(include=['float64'])

import matplotlib.pyplot as plt
import numpy as np

plt.scatter(housing_numerical['median_house_value'], housing_numerical['housing_median_age'] , s=12, marker='o')
plt.xlabel('house value')
plt.ylabel('age')
plt.show()

# %%
plt.scatter(housing_numerical['median_house_value'], housing_numerical['total_rooms']  , s=12, marker='o')
plt.xlabel('house value')
plt.ylabel('total rooms')
plt.show()

# %%
plt.scatter(housing_numerical['median_house_value'], housing_numerical['total_bedrooms']  , s=12, marker='o')
plt.xlabel('house value')
plt.ylabel('total bedrooms')
plt.show()

# %%
plt.scatter(housing_numerical['median_house_value'] , housing_numerical['population'] , s=12, marker='o')
plt.xlabel('house value')
plt.ylabel('population')
plt.show()

# %%
plt.scatter(housing_numerical['median_house_value'] , housing_numerical['households'] , s=12, marker='o')
plt.xlabel('house value')
plt.ylabel('households')
plt.show()

# %%
plt.scatter(housing_numerical['median_house_value'] , housing_numerical['median_income'] , s=12, marker='o')
plt.xlabel('house value')
plt.ylabel('median_income')
plt.show()

# %%
#Question 6
print("Based on the above graphs, the feature that has a linear relationship with median_house_value is median_income")
# Out:
# Based on the above graphs, the feature that has a linear relationship with median_house_value is median_income

# %%
#Question 5
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['bedrooms'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('bedrooms')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['bathrooms'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('bathrooms')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_living'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('sqft_living')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_lot'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('sqft_lot')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['floors'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('floors')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['waterfront'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('waterfront')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['view'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('view')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['condition'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('condition')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['grade'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('grade')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_above'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('sqft_above')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_basement'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('sqft_basement')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['yr_built'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('yr_built')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['yr_renovated'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('yr_renovated')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_living15'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('sqft_living15')
plt.show()

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_lot15'] , s=12, marker='o')
plt.xlabel('price')
plt.ylabel('sqft_lot15')
plt.show()

# %%
#Question 6
print("Based on the above graphs, the feature that has a linear relationship with median_house_value is sqft_living, grade, sqft_above, sqft_basement, and sqft_living15")
# Out:
# Based on the above graphs, the feature that has a linear relationship with median_house_value is sqft_living, grade, sqft_above, sqft_basement, and sqft_living15

# %%
#Question 7
import scipy as sp

lr = sp.stats.linregress(housing_numerical['median_income'], housing_numerical['median_house_value'])
df = pd.DataFrame({'Feature':['median_income'], 'Slope':[lr.slope], 'Intercept':[lr.intercept]})
lr
# Out:
# LinregressResult(slope=41793.84920189628, intercept=45085.57670326793, rvalue=0.6880752079585485, pvalue=0.0, stderr=306.8057538867835, intercept_stderr=1322.8716177148076)

# %%
plt.scatter(housing_numerical['median_house_value'] , housing_numerical['median_income'] , s=12, marker='o')
plt.axline(xy1=(0, lr.intercept), slope=lr.slope)
plt.xlabel('house value')
plt.ylabel('median_income')
plt.show()

# %%
lr = sp.stats.linregress(kc_house_data_numerical['sqft_living'], kc_house_data_numerical['price'])
df.loc[len(df.index)] = ['sqft_living', lr.slope, lr.intercept] 
lr
# Out:
# LinregressResult(slope=280.62356789744825, intercept=-43580.74309447396, rvalue=0.7020350546118002, pvalue=0.0, stderr=1.9363985519989135, intercept_stderr=4402.6896903039)

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_living'] , s=12, marker='o')
plt.axline(xy1=(0, lr.intercept), slope=lr.slope)
plt.xlabel('price')
plt.ylabel('sqft_living')
plt.show()
# Out:
# 280.62356789744825

# %%
lr = sp.stats.linregress(kc_house_data_numerical['grade'], kc_house_data_numerical['price'])
df.loc[len(df.index)] = ['grade', lr.slope, lr.intercept] 
lr
# Out:
# LinregressResult(slope=208457.5624583791, intercept=-1056044.9770097737, rvalue=0.6674342560202371, pvalue=0.0, stderr=1582.1033366994686, intercept_stderr=12255.87419002799)

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['grade'] , s=12, marker='o')
plt.axline(xy1=(0, lr.intercept), slope=lr.slope)
plt.xlabel('price')
plt.ylabel('grade')
plt.show()

# %%
lr = sp.stats.linregress(kc_house_data_numerical['sqft_above'], kc_house_data_numerical['price'])
df.loc[len(df.index)] = ['sqft_above', lr.slope, lr.intercept] 
lr
# Out:
# LinregressResult(slope=268.4731877618893, intercept=59953.192047000804, rvalue=0.605567298356078, pvalue=0.0, stderr=2.3999477545005106, intercept_stderr=4729.811897040538)

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_above'] , s=12, marker='o')
plt.axline(xy1=(0, lr.intercept), slope=lr.slope)
plt.xlabel('price')
plt.ylabel('sqft_above')
plt.show()

# %%
lr = sp.stats.linregress(kc_house_data_numerical['sqft_basement'], kc_house_data_numerical['price'])
df.loc[len(df.index)] = ['sqft_basement', lr.slope, lr.intercept] 
lr
# Out:
# LinregressResult(slope=268.6135827745053, intercept=461784.8526484638, rvalue=0.32381602071198373, pvalue=0.0, stderr=5.338736190077016, intercept_stderr=2829.2336602273112)

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_basement'] , s=12, marker='o')
plt.axline(xy1=(0, lr.intercept), slope=lr.slope)
plt.xlabel('price')
plt.ylabel('sqft_basement')
plt.show()

# %%
lr = sp.stats.linregress(kc_house_data_numerical['sqft_living15'], kc_house_data_numerical['price'])
df.loc[len(df.index)] = ['sqft_living15', lr.slope, lr.intercept] 
lr
# Out:
# LinregressResult(slope=313.555941573521, intercept=-82807.19520853879, rvalue=0.5853789035795677, pvalue=0.0, stderr=2.954151551430607, intercept_stderr=6208.0286306996495)

# %%
plt.scatter(kc_house_data_numerical['price'] , kc_house_data_numerical['sqft_living15'] , s=12, marker='o')
plt.axline(xy1=(0, lr.intercept), slope=lr.slope)
plt.xlabel('price')
plt.ylabel('sqft_living15')
plt.show()

# %%
df
# Out:
#          Feature          Slope     Intercept
# 0  median_income   41793.849202  4.508558e+04
# 1    sqft_living     280.623568 -4.358074e+04
# 2    sqft_living     280.623568 -4.358074e+04
# 3          grade  208457.562458 -1.056045e+06
# 4     sqft_above     268.473188  5.995319e+04
# 5  sqft_basement     268.613583  4.617849e+05
# 6  sqft_living15     313.555942 -8.280720e+04
